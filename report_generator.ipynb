# %%
import os
import pandas as pd
import pdfkit
import base64
df = pd.read_excel('Path_of_Excel_File')
# logos of the institute and corporation
top_right_logo_path = 'imageedit_3_6849239154.png'
top_right_logo_data = base64.b64encode(open(top_right_logo_path, 'rb').read()).decode('utf-8')

top_left_logo_path = 'bluelog.jpg'
top_left_logo_data = base64.b64encode(open(top_left_logo_path, 'rb').read()).decode('utf-8')

bottom_left_logo_path = 'smsslogo.png'
bottom_left_logo_data = base64.b64encode(open(bottom_left_logo_path, 'rb').read()).decode('utf-8')
# Define HTML template with styling
styled_html = f"""
<html>
<head>
<style>
  body {{
    font-family: Arial, sans-serif;
    color: #333;
    margin: 20px;
    position: relative;
  }}
  #container {{
    max-width: 800px;
    margin: 0 auto;
    padding: 20px;
    background-color: rgba(255, 255, 255, 0.8);
    border-radius: 10px;
    box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
  }}
  .top-right-logo {{
    position: absolute;
    top: 0;
    right: 0;
    max-width: 100px;
    max-height: 100px;
  }}
  .top-left-logo {{
    position: absolute;
    top: 0;
    left: 0;
    max-width: 100px;
    max-height: 100px;
  }}
  h2 {{
    text-align: center;
    margin-bottom: 20px;
  }}
  .organization-info {{
    text-align: center;
    margin-bottom: 20px;
  }}
  .additional-info {{
    display: flex;
    justify-content: space-between;
    margin-top: 20px;
  }}
  table {{
    width: 100%;
    border-collapse: collapse;
    margin-top: 20px;
  }}
  th, td {{
    border: 1px solid #ddd;
    padding: 8px;
    text-align: left;
  }}
  th {{
    background-color: #f2f2f2;
  }}
  .image-cell {{
    width: 20px;
    height: 20px;
    border: 1px solid #ddd;
    text-align: center;
    vertical-align: middle;
  }}
  .within-range {{
    background-color: #4CAF50; /* Green */
    color: white;
  }}
  .out-of-range {{
    background-color: #f44336; /* Red */
    color: white;
  }}
  .bottom-info {{
    display: flex;
    justify-content: space-between;
    margin-top: 20px;
    width: 100%;
    position: absolute;
    bottom: 20px;
  }}
  .bottom-left-logo {{
    max-width: 70px;
    max-height: 70px;
  }}
</style>
</head>
<body>
  <div id="container">
    <img src="data:image/png;base64,{top_right_logo_data}" alt="Top Right Logo" class="top-right-logo">
    <img src="data:image/png;base64,{top_left_logo_data}" alt="Top Left Logo" class="top-left-logo">
    <h2>Power Grid Corporation of India</h2>
    <div class="organization-info">
      <div>Time of starting: 9:00 A.M</div>
      <div>Sub-station Location: Kanpur(26.449923, 80.331871)</div>
    </div>
    {df.style.apply(lambda x: ['background-color: #4CAF50; color: white;' if v == 'Normal' else 'background-color: #f44336; color: white;' if v == 'Abnormal' else '' for v in x]).to_html(classes='table table-striped', index=False)}
    <div class="bottom-info">
      <img src="data:image/png;base64,{bottom_left_logo_data}" alt="Bottom Left Logo" class="bottom-left-logo">
    </div>
  </div>
</body>
</html>
"""

with open('output_html.html', 'w') as f:
    f.write(styled_html)
pdfkit.from_file('output_s.html', 'output_pdf.pdf')
